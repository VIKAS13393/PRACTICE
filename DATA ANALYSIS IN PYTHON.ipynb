# %% [raw]
# sWHILE CREATING DATAFRAME USING DICT ALL ELEMENT HAS TO BE PRESENT OTHERWISE IT WILL SHOW
# ARRAY LENGTH IS NOT SAME

# %%
import pandas as pd

df=pd.DataFrame({"Day":[1,2,3,4,5,6,7,8],'visitors':[100,230,300,400,500,600,700,800],"rate":[20,30,40,50,60,70,80,90]})
df

# tabhi jab web scrapping mai array same length mai nahi hota toh error dikhata hai
# kyuki vaha um dict se dataframe banate hai isliye array size same hona chahiye
# Out:
#    Day  visitors  rate
# 0    1       100    20
# 1    2       230    30
# 2    3       300    40
# 3    4       400    50
# 4    5       500    60
# 5    6       600    70
# 6    7       700    80
# 7    8       800    90

# %%
# IF YOU ARE CREATING DATAFRAME USING LIST THEN MISSING ELEMENT IS NOT TAKEN AS A PROBELEM AS IN DICTIONARY
# here missing element is taken as NaN


df1=pd.DataFrame([[1,2,3],[3,4,5],[2,3]])
df1
# Out:
#    0  1    2
# 0  1  2  3.0
# 1  3  4  5.0
# 2  2  3  NaN

# %%
df.tail()  # last five rows
# Out:
#    Day  visitors  rate
# 3    4       400    50
# 4    5       500    60
# 5    6       600    70
# 6    7       700    80
# 7    8       800    90

# %%
df.head()  # first five rows
# Out:
#    Day  visitors  rate
# 0    1       100    20
# 1    2       230    30
# 2    3       300    40
# 3    4       400    50
# 4    5       500    60

# %%
df.head(3)
# Out:
#    Day  visitors  rate
# 0    1       100    20
# 1    2       230    30
# 2    3       300    40

# %%
df.sample()   # it will randomly show any sample
# Out:
#    Day  visitors  rate
# 4    5       500    60

# %% [markdown]
# # READING CSV FILES WITH PANDAS

# %%
# read.csv(filepath,header='infer',sep=',',delimiter=None,names=None,index_col=None)
# sep(seperator is by default ',')

# %%
import pandas as pd
df=pd.read_csv('concrete.csv')
df
# Out:
#       Cement  Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age  \
# 0      540.0    0.0      0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0      0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5      0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5      0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4      0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...      ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0     90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0    115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4    108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7      0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5     78.3  200.6               8.6   864.5  761.5   28
#
#         CMS
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# ...

# %%
type(df['Cement'][0])    # datatype of cememnt column
# Out:
# numpy.float64

# %%
df['Cement'] 
# we know data frame is collection of list or dict in tabular form
# df[cement] is one of the list in dataframe
# Out:
# 0       540.0
# 1       540.0
# 2       332.5
# 3       332.5
# 4       198.6
#         ...
# 1025    276.4
# 1026    322.2
# 1027    148.5
# 1028    159.1
# 1029    260.9
# Name: Cement, Length: 1030, dtype: float64

# %%
df=pd.read_csv('concrete.csv',index_col='Cement')  #setting cement as index column
df
# Out:
#         Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age    CMS
# Cement
# 540.0     0.0      0.0  162.0               2.5  1040.0  676.0   28  79.99
# 540.0     0.0      0.0  162.0               2.5  1055.0  676.0   28  61.89
# 332.5   142.5      0.0  228.0               0.0   932.0  594.0  270  40.27
# 332.5   142.5      0.0  228.0               0.0   932.0  594.0  365  41.05
# 198.6   132.4      0.0  192.0               0.0   978.4  825.5  360  44.30
# ...       ...      ...    ...               ...     ...    ...  ...    ...
# 276.4   116.0     90.3  179.6               8.9   870.1  768.3   28  44.28
# 322.2     0.0    115.6  196.0              10.4   817.9  813.4   28  31.18
# 148.5   139.4    108.6  192.7               6.1   892.4  780.0   28  23.70
# 159.1   186.7      0.0  175.6              11.3   989.6  788.9   28  32.77
# 260.9   100.5     78.3  200.6               8.6   864.5  761.5   28  32.40
#
# [1030 rows x 8 columns]

# %%
pandas.concrete_csv?
# Out:
# Object `pandas.concrete_csv` not found.

# %%
# explicitly pass header=0 to be able to replace existing names:
# by default header=infer, which means it will take the same name of column which is there in the dataset

# %%
import pandas as pd
df=pd.read_csv('concrete.csv',
              header=0,   # header allow to change the exisiting column names
              names=['A','B','C','D','E','F','G','H','J'])  # column name changes
df
# Out:
#           A      B      C      D     E       F      G    H      J
# 0     540.0    0.0    0.0  162.0   2.5  1040.0  676.0   28  79.99
# 1     540.0    0.0    0.0  162.0   2.5  1055.0  676.0   28  61.89
# 2     332.5  142.5    0.0  228.0   0.0   932.0  594.0  270  40.27
# 3     332.5  142.5    0.0  228.0   0.0   932.0  594.0  365  41.05
# 4     198.6  132.4    0.0  192.0   0.0   978.4  825.5  360  44.30
# ...     ...    ...    ...    ...   ...     ...    ...  ...    ...
# 1025  276.4  116.0   90.3  179.6   8.9   870.1  768.3   28  44.28
# 1026  322.2    0.0  115.6  196.0  10.4   817.9  813.4   28  31.18
# 1027  148.5  139.4  108.6  192.7   6.1   892.4  780.0   28  23.70
# 1028  159.1  186.7    0.0  175.6  11.3   989.6  788.9   28  32.77
# 1029  260.9  100.5   78.3  200.6   8.6   864.5  761.5   28  32.40
#
# [1030 rows x 9 columns]

# %%
df1=pd.read_csv('concrete.csv',index_col='Cement')
df1
# Out:
#         Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age    CMS
# Cement
# 540.0     0.0      0.0  162.0               2.5  1040.0  676.0   28  79.99
# 540.0     0.0      0.0  162.0               2.5  1055.0  676.0   28  61.89
# 332.5   142.5      0.0  228.0               0.0   932.0  594.0  270  40.27
# 332.5   142.5      0.0  228.0               0.0   932.0  594.0  365  41.05
# 198.6   132.4      0.0  192.0               0.0   978.4  825.5  360  44.30
# ...       ...      ...    ...               ...     ...    ...  ...    ...
# 276.4   116.0     90.3  179.6               8.9   870.1  768.3   28  44.28
# 322.2     0.0    115.6  196.0              10.4   817.9  813.4   28  31.18
# 148.5   139.4    108.6  192.7               6.1   892.4  780.0   28  23.70
# 159.1   186.7      0.0  175.6              11.3   989.6  788.9   28  32.77
# 260.9   100.5     78.3  200.6               8.6   864.5  761.5   28  32.40
#
# [1030 rows x 8 columns]

# %%
df1['Blast'].min()
# Out:
# 0.0

# %%
df1['Blast'].max()
# Out:
# 359.4

# %%
df1['Blast'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df2=df1.loc[:,['Blast']]  # select all rows and column('Cement' and 'Blast') not using index here
df2.head(5)
# Out:
#         Blast
# Cement
# 540.0     0.0
# 540.0     0.0
# 332.5   142.5
# 332.5   142.5
# 198.6   132.4

# %%
df1.iloc[:,1:3]   # selected all the rows and 1,2 column( 3 exclusive)
# Out:
#         Fly Ash  Water
# Cement
# 540.0       0.0  162.0
# 540.0       0.0  162.0
# 332.5       0.0  228.0
# 332.5       0.0  228.0
# 198.6       0.0  192.0
# ...         ...    ...
# 276.4      90.3  179.6
# 322.2     115.6  196.0
# 148.5     108.6  192.7
# 159.1       0.0  175.6
# 260.9      78.3  200.6
#
# [1030 rows x 2 columns]

# %%
df1['Age'].unique()
# Out:
# array([ 28, 270, 365, 360,  90, 180,   3,   7,  56,  91,  14, 100, 120,
#          1], dtype=int64)

# %%
df1['Age'].describe()
# Out:
# count    1030.000000
# mean       45.662136
# std        63.169912
# min         1.000000
# 25%         7.000000
# 50%        28.000000
# 75%        56.000000
# max       365.000000
# Name: Age, dtype: float64

# %% [markdown]
# # DROPPING OF ROWS AND COLUMNS IN PANDAS

# %%
df1.columns
# Out:
# Index(['Blast', 'Fly Ash', 'Water', 'Superplasticizer', 'CA', 'FA', 'Age',
#        'CMS'],
#       dtype='object')

# %%
import pandas as pd
d1=pd.read_csv('concrete.csv')
d1
# Out:
#       Cement  Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age  \
# 0      540.0    0.0      0.0  162.0               2.5  1040.0  676.0   28
# 1      540.0    0.0      0.0  162.0               2.5  1055.0  676.0   28
# 2      332.5  142.5      0.0  228.0               0.0   932.0  594.0  270
# 3      332.5  142.5      0.0  228.0               0.0   932.0  594.0  365
# 4      198.6  132.4      0.0  192.0               0.0   978.4  825.5  360
# ...      ...    ...      ...    ...               ...     ...    ...  ...
# 1025   276.4  116.0     90.3  179.6               8.9   870.1  768.3   28
# 1026   322.2    0.0    115.6  196.0              10.4   817.9  813.4   28
# 1027   148.5  139.4    108.6  192.7               6.1   892.4  780.0   28
# 1028   159.1  186.7      0.0  175.6              11.3   989.6  788.9   28
# 1029   260.9  100.5     78.3  200.6               8.6   864.5  761.5   28
#
#         CMS
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05
# ...

# %%
d2=d1.drop([14,15,16])   # dropping rows in the dataframe
d2.head(20)
# Out:
#     Cement  Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age    CMS
# 0    540.0    0.0      0.0  162.0               2.5  1040.0  676.0   28  79.99
# 1    540.0    0.0      0.0  162.0               2.5  1055.0  676.0   28  61.89
# 2    332.5  142.5      0.0  228.0               0.0   932.0  594.0  270  40.27
# 3    332.5  142.5      0.0  228.0               0.0   932.0  594.0  365  41.05
# 4    198.6  132.4      0.0  192.0               0.0   978.4  825.5  360  44.30
# 5    266.0  114.0      0.0  228.0               0.0   932.0  670.0   90  47.03
# 6    380.0   95.0      0.0  228.0               0.0   932.0  594.0  365  43.70
# 7    380.0   95.0      0.0  228.0               0.0   932.0  594.0   28  36.45
# 8    266.0  114.0      0.0  228.0               0.0   932.0  670.0   28  45.85
# 9    475.0    0.0      0.0  228.0               0.0   932.0  594.0   28  39.29
# 10   198.6  132.4      0.0  192.0               0.0   978.4  825.5   90  38.07
# ...

# %%
d3=d1.drop('Cement',axis=1) # axis=1 means drop column
d3
# Out:
#       Blast  Fly Ash  Water  Superplasticizer      CA     FA  Age    CMS
# 0       0.0      0.0  162.0               2.5  1040.0  676.0   28  79.99
# 1       0.0      0.0  162.0               2.5  1055.0  676.0   28  61.89
# 2     142.5      0.0  228.0               0.0   932.0  594.0  270  40.27
# 3     142.5      0.0  228.0               0.0   932.0  594.0  365  41.05
# 4     132.4      0.0  192.0               0.0   978.4  825.5  360  44.30
# ...     ...      ...    ...               ...     ...    ...  ...    ...
# 1025  116.0     90.3  179.6               8.9   870.1  768.3   28  44.28
# 1026    0.0    115.6  196.0              10.4   817.9  813.4   28  31.18
# 1027  139.4    108.6  192.7               6.1   892.4  780.0   28  23.70
# 1028  186.7      0.0  175.6              11.3   989.6  788.9   28  32.77
# 1029  100.5     78.3  200.6               8.6   864.5  761.5   28  32.40
#
# [1030 rows x 8 columns]

# %%
d4=d1.drop(['Cement','Blast'],axis=1)   # drop multiple columns
d4
# Out:
#       Fly Ash  Water  Superplasticizer      CA     FA  Age    CMS
# 0         0.0  162.0               2.5  1040.0  676.0   28  79.99
# 1         0.0  162.0               2.5  1055.0  676.0   28  61.89
# 2         0.0  228.0               0.0   932.0  594.0  270  40.27
# 3         0.0  228.0               0.0   932.0  594.0  365  41.05
# 4         0.0  192.0               0.0   978.4  825.5  360  44.30
# ...       ...    ...               ...     ...    ...  ...    ...
# 1025     90.3  179.6               8.9   870.1  768.3   28  44.28
# 1026    115.6  196.0              10.4   817.9  813.4   28  31.18
# 1027    108.6  192.7               6.1   892.4  780.0   28  23.70
# 1028      0.0  175.6              11.3   989.6  788.9   28  32.77
# 1029     78.3  200.6               8.6   864.5  761.5   28  32.40
#
# [1030 rows x 7 columns]

# %% [markdown]
# # DATA MUNGING

# %%
# HERE WE CAN CONVERT A PARTICULAR DATA INTO DIFFERENT FORMAT.FOR EXAMPLE .CSV FILE,YOU CAN CONVERT
# INTO .HTML OR ANY OTHER DATA FORMAT

# %%
import pandas as pd

con=pd.read_csv('concrete.csv') #  read csv file and store it into con variable 

con.to_html('new.html')    # convert csv file into html form using to_csv

# %% [markdown]
# # DATA OPERATIONS

# %%
import pandas as pd
ds=pd.read_csv('EmployeeS.csv')
ds.head()
# Out:
#                     NAME                 JOB TITLE       DEPARTMENT  \
# 0        AARON,  ELVIA J          WATER RATE TAKER      WATER MGMNT
# 1      AARON,  JEFFERY M            POLICE OFFICER           POLICE
# 2    AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  FLEET MANAGEMNT
# 3    ABAD JR,  VICENTE M         CIVIL ENGINEER IV      WATER MGMNT
# 4  ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC      WATER MGMNT
#
#   EMPLOYEE ANNUAL SALARY ESTIMATED ANNUAL SALARY MINUS FURLOUGHS
# 0              $81000.00                               $73862.00
# 1              $74628.00                               $74628.00
# 2              $77280.00                               $70174.00
# 3              $96276.00                               $96276.00
# 4              $84032.00                               $76627.00

# %%
# here each column can be acessed seperately
ds['NAME']
# Out:
# 0              AARON,  ELVIA J
# 1            AARON,  JEFFERY M
# 2          AARON,  KIMBERLEI R
# 3          ABAD JR,  VICENTE M
# 4        ABBATACOLA,  ROBERT J
#                  ...
# 34213        ZYMANTAS,  MARK E
# 34214     ZYNIEWICZ,  ROBERT J
# 34215      ZYRKOWSKI,  CARLO E
# 34216          ZYSKO,  RICHARD
# 34217      ZYSKOWSKI,  DARIUSZ
# Name: NAME, Length: 34218, dtype: object

# %%
ds['NAME'][:5] # show 0:5(exclusive) rows
# Out:
# 0          AARON,  ELVIA J
# 1        AARON,  JEFFERY M
# 2      AARON,  KIMBERLEI R
# 3      ABAD JR,  VICENTE M
# 4    ABBATACOLA,  ROBERT J
# Name: NAME, dtype: object

# %%
# SELECTING MULTIPLE COLUMNS

ds[['NAME','JOB TITLE']]
# Out:
#                         NAME                 JOB TITLE
# 0            AARON,  ELVIA J          WATER RATE TAKER
# 1          AARON,  JEFFERY M            POLICE OFFICER
# 2        AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M         CIVIL ENGINEER IV
# 4      ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC
# ...                      ...                       ...
# 34213      ZYMANTAS,  MARK E            POLICE OFFICER
# 34214   ZYNIEWICZ,  ROBERT J      CONSTRUCTION LABORER
# 34215    ZYRKOWSKI,  CARLO E            POLICE OFFICER
# 34216        ZYSKO,  RICHARD                LIEUTENANT
# 34217    ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST
#
# [34218 rows x 2 columns]

# %%
ds[['NAME','JOB TITLE']][0:7]
# Out:
#                     NAME                 JOB TITLE
# 0        AARON,  ELVIA J          WATER RATE TAKER
# 1      AARON,  JEFFERY M            POLICE OFFICER
# 2    AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER
# 3    ABAD JR,  VICENTE M         CIVIL ENGINEER IV
# 4  ABBATACOLA,  ROBERT J       ELECTRICAL MECHANIC
# 5       ABBATE,  TERRY M            POLICE OFFICER
# 6  ABBATEMARCO,  JAMES J               FIREFIGHTER

# %%
ds['DEPARTMENT'].value_counts()
# Out:
# POLICE                   14147
# FIRE                      5085
# STREETS & SAN             2193
# WATER MGMNT               1834
# OEMC                      1381
# AVIATION                  1289
# TRANSPORTN                1230
# PUBLIC LIBRARY            1063
# FAMILY & SUPPORT           863
# HEALTH                     862
# FLEET MANAGEMNT            612
# GENERAL SERVICES           477
# LAW                        413
# REVENUE                    411
# CITY COUNCIL               364
# BUILDINGS                  291
# COMMUNITY DEVELOPMENT      236
# BUSINESS AFFAIRS           191
# FINANCE                    190
# CITY CLERK                 127
# BOARD OF ELECTION          114
# DoIT                        95
# IPRA                        87
# HUMAN RESOURCES             73
# MAYOR'S OFFICE              73
# ANIMAL CONTRL               66
# CULTURAL AFFAIRS            65
# ENVIRONMENT                 61
# PROCUREMENT                 59
# INSPECTOR GEN               54
# ...

# %%
c1=ds['NAME'][0:5]  # we  can store the column in seperate variable and use work on it seperately
c1[0:4]
# Out:
# 0        AARON,  ELVIA J
# 1      AARON,  JEFFERY M
# 2    AARON,  KIMBERLEI R
# 3    ABAD JR,  VICENTE M
# Name: NAME, dtype: object

# %%
n=ds[['NAME','DEPARTMENT']][0:5]   # 0:5 is row, and 'NAME' and 'DEPARTMENT column is already mentioned'
n
# WE CAN STORE THE DATAFRAME IN NORMAL VARIABLE AND USE IT
# Out:
#                     NAME       DEPARTMENT
# 0        AARON,  ELVIA J      WATER MGMNT
# 1      AARON,  JEFFERY M           POLICE
# 2    AARON,  KIMBERLEI R  FLEET MANAGEMNT
# 3    ABAD JR,  VICENTE M      WATER MGMNT
# 4  ABBATACOLA,  ROBERT J      WATER MGMNT

# %%
n['NAME']
# Out:
# 0          AARON,  ELVIA J
# 1        AARON,  JEFFERY M
# 2      AARON,  KIMBERLEI R
# 3      ABAD JR,  VICENTE M
# 4    ABBATACOLA,  ROBERT J
# Name: NAME, dtype: object

# %%
import pandas as pd
ds=pd.read_csv('HR ATTRITION.csv')
ds.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
ds['Age'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
new_d1=ds[ds['Attrition']=='Yes']   # jaha jaha attrition yes hi vo sab column and rows print karo
new_d1[0:5]
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 0    41       Yes  Travel_Rarely       1102                   Sales
# 2    37       Yes  Travel_Rarely       1373  Research & Development
# 14   28       Yes  Travel_Rarely        103  Research & Development
# 21   36       Yes  Travel_Rarely       1218                   Sales
# 24   34       Yes  Travel_Rarely        699  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                  1          2  Life Sciences              1               1
# 2                  2          2          Other              1               4
# 14                24          3  Life Sciences              1              19
# 21                 9          4  Life Sciences              1              27
# 24                 6          1        Medical              1              31
#
#     ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
cc1=ds['Department'].value_counts()
cc1
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
cc1[0:30].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dv=ds[['Attrition']]=='Yes' 

dv# boolean operations
# Out:
#       Attrition
# 0          True
# 1         False
# 2          True
# 3         False
# 4         False
# ...         ...
# 1465      False
# 1466      False
# 1467      False
# 1468      False
# 1469      False
#
# [1470 rows x 1 columns]

# %%
dv=ds['Attrition']=='Yes'
dv
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: Attrition, Length: 1470, dtype: bool

# %%
dept=ds['Department']=='Sales'
dept
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468     True
# 1469    False
# Name: Department, Length: 1470, dtype: bool

# %%
ds[dept&dv]
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 0      41       Yes      Travel_Rarely       1102      Sales
# 21     36       Yes      Travel_Rarely       1218      Sales
# 33     39       Yes      Travel_Rarely        895      Sales
# 36     50       Yes      Travel_Rarely        869      Sales
# 89     46       Yes      Travel_Rarely        669      Sales
# ...   ...       ...                ...        ...        ...
# 1395   31       Yes  Travel_Frequently        754      Sales
# 1396   53       Yes      Travel_Rarely       1168      Sales
# 1438   23       Yes  Travel_Frequently        638      Sales
# 1452   50       Yes  Travel_Frequently        878      Sales
# 1461   50       Yes      Travel_Rarely        410      Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                    1          2     Life Sciences              1
# 21                   9          4     Life Sciences              1
# ...

# %%
ds.isnull()   # isnull or notnull function for missed data
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
ds[ds['Attrition']=='Yes']   # print ds table where attrition is yes
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
ds['Department'].isnull()  # checking null value in particular column
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: Department, Length: 1470, dtype: bool

# %%
dtest=ds.copy
dtest
# Out:
# <bound method NDFrame.copy of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
ds1=ds.replace('Yes','Correct')    #replac value in table with other vavlues
ds1
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41   Correct      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37   Correct      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# DROP ROW WITH MISSING VALUE:  DROPNA FUNCTION

ds2=ds.dropna()
ds2
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# dropping all columns with nan values  

ds4=ds.dropna(axis=1)
ds4alue 

# since no nan values is present in any column no column is delelted
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # FILLNA

# %%
# When there is many NaN value present inside a column 
# instead of dropping it we can fill it with either 0,any othr values

# ds.fillna(0,inplace=True)  # fill NaN value  with 0
# ds.fillna(ds.mean(),inplace-True)    , fill all the NaN values with means of the the dataset( when dataset has all numerical column)
# ds3['Age'].fillna(ds3['Age'].mean(),inplace=True)  ,fill NaN in age column with means of all age in that column
# ds3['salary'].fillna(ds3['salary'].mean(),inplace=True)
